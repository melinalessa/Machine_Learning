# %% [markdown]
# <a href="https://colab.research.google.com/github/melinalessa/Machine_Learning/blob/main/exe3_tratamento_nulos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Carregue o arquivo chamado notas.csv (link abaixo) e responda às
# seguintes perguntas:
#
# Quantos valores nulos existem nessa tabela?
#
# Que tipo de tratamento seria indicado para cada coluna com valores faltantes?
#
# Se for aplicável, exclua a coluna que a remoção completa é a abordagem mais adequada.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/LyndainesSantos/Machine-Learning/main/tratamento_dados/Exercicios/notas.csv")
# Out:
# <ipython-input-17-56c26033a8ac>:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("https://raw.githubusercontent.com/LyndainesSantos/Machine-Learning/main/tratamento_dados/Exercicios/notas.csv")

# %%
# Verificar a quantidade de registros nulos
df.isnull().sum()
# Out:
# Unnamed: 0                            0
# CHAVE DE ACESSO                       0
# MODELO                                1
# SÉRIE                                 8
# NÚMERO                                2
# NATUREZA DA OPERAÇÃO                  0
# DATA EMISSÃO                     107684
# EVENTO MAIS RECENTE                   0
# DATA/HORA EVENTO MAIS RECENTE         0
# CPF/CNPJ Emitente                     0
# RAZÃO SOCIAL EMITENTE                 0
# INSCRIÇÃO ESTADUAL EMITENTE           0
# UF EMITENTE                           0
# MUNICÍPIO EMITENTE                    0
# CNPJ DESTINATÁRIO                     0
# NOME DESTINATÁRIO                     0
# UF DESTINATÁRIO                      47
# INDICADOR IE DESTINATÁRIO            47
# DESTINO DA OPERAÇÃO                   0
# CONSUMIDOR FINAL                      0
# PRESENÇA DO COMPRADOR                 0
# VALOR NOTA FISCAL                     0
# dtype: int64

# %% [markdown]
# Os nulos podemos verificar na coluna: "MODELO", "SERIE", "NUMERO", "DATA EMISSAO", "UF DESTINATARIO", "INDICADOR IE DESTINATARIO". Para análise as informações mais importantes estão preenchidas. Mas nesse caso, vamos fazer a exclusão dos nulos na coluna "DATA DE EMISSAO".

# %%
# Eliminar coluna DATA EMISSÃO
df = df.drop('DATA EMISSÃO', axis=1)

# %%
df
# Out:
#         Unnamed: 0 CHAVE DE ACESSO  \
# 0                0     4,22301E+43
# 1                1     4,22301E+43
# 2                2     3,32301E+43
# 3                3     4,22301E+43
# 4                4     5,12301E+43
# ...            ...             ...
# 107682      107682     2,42301E+43
# 107683      107683     3,12301E+43
# 107684      107684     3,12301E+43
# 107685      107685     3,52301E+43
# 107686      107686     4,32302E+43
#
#                                                    MODELO  SÉRIE    NÚMERO  \
# 0       55 - NF-E EMITIDA EM SUBSTITUIÇÃO AO MODELO 1 ...    3.0  755441.0
# 1       55 - NF-E EMITIDA EM SUBSTITUIÇÃO AO MODELO 1 ...    3.0  755428.0
# 2       55 - NF-E EMITIDA EM SUBSTITUIÇÃO AO MODELO 1 ...    1.0      16.0
# 3                                                     NaN    3.0  755891.0
# 4       55 - NF-E EMITIDA EM SUBSTITUIÇÃO AO MODELO 1 ...    4.0    2393.0
# ...                                                   ...    ...       ...
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                        0
# CHAVE DE ACESSO                   0
# MODELO                            1
# SÉRIE                             8
# NÚMERO                            2
# NATUREZA DA OPERAÇÃO              0
# EVENTO MAIS RECENTE               0
# DATA/HORA EVENTO MAIS RECENTE     0
# CPF/CNPJ Emitente                 0
# RAZÃO SOCIAL EMITENTE             0
# INSCRIÇÃO ESTADUAL EMITENTE       0
# UF EMITENTE                       0
# MUNICÍPIO EMITENTE                0
# CNPJ DESTINATÁRIO                 0
# NOME DESTINATÁRIO                 0
# UF DESTINATÁRIO                  47
# INDICADOR IE DESTINATÁRIO        47
# DESTINO DA OPERAÇÃO               0
# CONSUMIDOR FINAL                  0
# PRESENÇA DO COMPRADOR             0
# VALOR NOTA FISCAL                 0
# dtype: int64
